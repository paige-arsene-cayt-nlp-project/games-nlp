# %%
import acquire

# %%
data = acquire.acquire_data()
# Out:
# https://raw.githubusercontent.com/rabernat/intro_to_physical_oceanography/master/README.md
# https://raw.githubusercontent.com/dankelley/oce/develop/README.md
# https://raw.githubusercontent.com/wafo-project/pywafo/master/README.rst
# https://raw.githubusercontent.com/ocefpaf/python4oceanographers/master/README.md
# https://raw.githubusercontent.com/matplotlib/cmocean/master/README.md
# https://raw.githubusercontent.com/stoqs/stoqs/master/README.md
# https://raw.githubusercontent.com/aodn/imos-toolbox/master/README.md
# https://raw.githubusercontent.com/castelao/CoTeDe/master/README.rst
# https://raw.githubusercontent.com/FinalTheory/oceanography-numerical-calculations/master/README.md
# https://raw.githubusercontent.com/introocean/introocean-en/master/README.md
# https://raw.githubusercontent.com/OceanLabPy/OceanLab/master/README.md
# https://raw.githubusercontent.com/TEOS-10/GSW-Fortran/master/README
# https://raw.githubusercontent.com/njwilson23/narwhal/master/README.md
#
# ...
