# %% [markdown]
# # Acquiring data

# %%
# Ignoring warning messages from python
import warnings
warnings.filterwarnings('ignore')

# General use imports
import pandas as pd
import numpy as np
from requests import get


# # Visualization imports
# import matplotlib.pyplot as plt
# import seaborn as sns
# import plotly.graph_objects as go
# import plotly
# import plotly.express as px

# Specific Modules
from bs4 import BeautifulSoup
import os
import json
import requests
from env import github_token, github_username
import acquire

# %%
# Set up
headers = {"Authorization": f"token {github_token}", "User-Agent": github_username}

url = 'https://github.com/search?q=oceanography&type=repositories'

# %%
response = get(url, headers=headers)

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
# Displaying soup
soup
# Out:
# <!DOCTYPE html>
#
# <html data-a11y-animated-images="system" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# ...

# %% [markdown]
# >#### Soup is not useful with selector copy on the lines of code for the url of repos
# >#### Use of selector needs to be done with mouse pointer selector
#         - Titles of all the repos seem to be in the '<a class="v-align-middle"'
#         - data-hydro-click seems to be content

# %%
# Getting the specific line 'a class="v-align-middle"'
soup.find_all('a',{'class':'v-align-middle'})
# Out:
# [<a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"oceanography","result_position":1,"click_id":41701566,"result":{"id":41701566,"global_relay_id":"MDEwOlJlcG9zaXRvcnk0MTcwMTU2Ng==","model_name":"Repository","url":"https://github.com/rabernat/intro_to_physical_oceanography"},"originating_url":"https://github.com/search?q=oceanography&amp;type=repositories","user_id":null}}' data-hydro-click-hmac="94845bca39214222ef4af27443264c2ecb11ddf285c22d32d01a5344db595ef3" href="/rabernat/intro_to_physical_oceanography">rabernat/intro_to_physical_<em>oceanography</em></a>,
# ...

# %%
# Checking the length to see this got all the 'a class="v-align-middle"'
len(soup.find_all('a',{'class':'v-align-middle'}))
# Out:
# 10

# %% [markdown]
# Class and href are empty without associating them to a it seems

# %%
soup.find_all('a', 'class')
# Out:
# []

# %%
<a class="v-align-middle" data-hydro-click="{&quot;event_type&quot;:&quot;search_result.click&quot;,&quot;payload&quot;:{&quot;page_number&quot;:1,&quot;per_page&quot;:10,&quot;query&quot;:&quot;oceanography&quot;,&quot;result_position&quot;:1,&quot;click_id&quot;:41701566,&quot;result&quot;:{&quot;id&quot;:41701566,&quot;global_relay_id&quot;:&quot;MDEwOlJlcG9zaXRvcnk0MTcwMTU2Ng==&quot;,&quot;model_name&quot;:&quot;Repository&quot;,&quot;url&quot;:&quot;https://github.com/rabernat/intro_to_physical_oceanography&quot;},&quot;originating_url&quot;:&quot;https://github.com/search?q=oceanography&amp;type=repositories&quot;,&quot;user_id&quot;:102164310}}" data-hydro-click-hmac="5b5c856aa04fa8858c8163fe3cfc8538a5a828197fcea8eec2e1bc0fd65a3388" href="/rabernat/intro_to_physical_oceanography">rabernat/intro_to_physical_<em>oceanography</em></a>

# %%
#js-pjax-container > div > div.col-12.col-md-9.float-left.px-2.pt-3.pt-md-0.codesearch-results > div > div.d-flex.flex-column.flex-md-row.flex-justify-between.border-bottom.pb-3.position-relative
